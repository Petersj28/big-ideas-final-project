# %%
import pandas as pd

#EMS = pd.read_csv("EMS.csv")
#query = EMS['description_short'] == "ASSAULT"
#ASSAULT = EMS[query]
ASSAULT = pd.read_csv("data12.csv")
value_counts = ASSAULT['city_name'].value_counts()
#value_counts = value_counts[value_counts > 50]
POP = pd.read_csv("countysubdivisions_pittsburghmsa_20102020_pl171v2 (1).csv")
count = 0;
for city in value_counts.items():
    Pop_query = POP['NAME'].str.contains(city[0], case=False)
    temp = POP[Pop_query]
    sm = temp['2010_Total_Population'].sum()
    if (sm!=0):
        value_counts[city[0]] = 1000*(float(value_counts[city[0]])/float(sm))
        count = count + 1
value_counts["EAST PITTSBURGH"] = 0
value_counts = value_counts.sort_values(ascending=False)
print("1. SEWICKLEY:" + str(value_counts["SEWICKLEY"]))
print("2. FRANKLIN PARK:" + str(value_counts["FRANKLIN PARK"]))
print("3. LEET:" + str(value_counts["LEET"]))
value_counts.plot(kind='bar', color='skyblue', edgecolor='black', figsize=(15, 5), fontsize=6, xlabel='Municipality (2019-2020)', ylabel="Assaults per 1000 people")
"""Source: https://data.wprdc.org/dataset/allegheny-county-911-dispatches-ems-and-fire/resource/ff33ca18-2e0c-4cb5-bdcd-60a5dc3c0418, """
# Out:
# /var/folders/d4/kz3f457s1vz29p6p82_m23z40000gn/T/ipykernel_50310/1987332694.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.927446784987286' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   value_counts[city[0]] = float(1000.0)*(float(value_counts[city[0]])/float(sm))
# 1. SEWICKLEY:0.04145936981757877
# 2. FRANKLIN PARK:0.29695619896065334
# 3. LEET:0.3506311360448808
# 'Source: https://data.wprdc.org/dataset/allegheny-county-911-dispatches-ems-and-fire/resource/ff33ca18-2e0c-4cb5-bdcd-60a5dc3c0418, '
