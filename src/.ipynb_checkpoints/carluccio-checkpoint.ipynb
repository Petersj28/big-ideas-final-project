# %%
import os
import pandas as pd

data = pd.read_csv(os.path.join('../data/Neighborhoods_with_SNAP_Data.csv'))
print(data)
# Out:
#     OBJECTID  Neighborhood_2010_FID_BlockG  Neighborhood_2010_STATEFP10  \
# 0          1                             0                           42
# 1          2                             1                           42
# 2          3                             2                           42
# 3          4                             3                           42
# 4          5                             5                           42
# ..       ...                           ...                          ...
# 85        86                           265                           42
# 86        87                           298                           42
# 87        88                            32                           42
# 88        89                            57                           42
# 89        90                            96                           42
#
#     Neighborhood_2010_COUNTYFP10  Neighborhood_2010_TRACTCE10  \
# ...
